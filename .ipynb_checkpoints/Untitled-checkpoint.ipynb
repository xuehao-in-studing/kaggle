# %%
from scipy.stats import binom,norm
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots(1, 1)

n, p = 50000, 0.4
mean, var, skew, kurt = binom.stats(n, p, moments='mvsk')
print(f'mean:{mean},var:{var},skew:{skew},krut:{kurt}')

x = np.arange(binom.ppf(0.01, n, p),
              binom.ppf(0.99, n, p))
y=(x-mean)/(var)
ax.plot(x, binom.pmf(x, n, p), 'bo', ms=8, label='binom pmf')
# ax.vlines(x, 0, binom.pmf(x, n, p), colors='b', lw=5, alpha=0.5)

rv = binom(n, p)
# ax.vlines(x, 0, rv.pmf(x), colors='k', linestyles='-', lw=1,label='frozen pmf')
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# mean:20000.0,var:12000.0,skew:0.0018257418583505533,krut:-3.666666666666668e-05

# %%
fig, ax = plt.subplots(1, 1)
mean, var, skew, kurt = norm.stats(moments='mvsk')
print(f'mean:{mean},var:{var},skew:{skew},krut:{kurt}')
x = np.linspace(norm.ppf(0.01),
                norm.ppf(0.99), 100)
ax.plot(x, norm.pdf(x),
       'r-', lw=5, alpha=0.6, label='norm pdf')
# plt.show()
rv = norm()
ax.plot(x, rv.pdf(x), 'k-', lw=2, label='frozen pdf')
vals = norm.ppf([0.001, 0.5, 0.999])
np.allclose([0.001, 0.5, 0.999], norm.cdf(vals))
r = norm.rvs(size=1000)
ax.hist(r, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# mean:0.0,var:1.0,skew:0.0,krut:0.0

# %%
from PIL import Image
from matplotlib.pyplot import *

file_path=r'E:\Program\Python\Kaggle\1.png'
a=Image. open(file_path)  #读入图像
ra,ga,ba=a. split() #图像分割成R、G、B三个通道
c=Image. merge('RGB',(ra,ga,ba)) #三个通道合成一张彩色图像
subplot(221); imshow(ra); subplot(222); imshow(ga)
subplot(223); imshow(ba); subplot(224); imshow(c); 
show()

# %%
import torch
import numpy as np

# %%
torch.random.seed()

a=torch.tensor([2.,3.,4.],requires_grad=True)
b=torch.ones_like(a,requires_grad=True)
Q=a**3*2+2*b
Q
# Out:
# tensor([ 18.,  56., 130.], grad_fn=<AddBackward0>)

# %%
b.requires_grad
# Out:
# True

# %%
Q_mean = Q.mean()
Q_mean
# Out:
# tensor(68., grad_fn=<MeanBackward0>)

# %%
Q_mean.backward()

# %%
print(b.grad)
# Out:
# tensor([0.6667, 0.6667, 0.6667])

# %%
b.grad
# Out:
# tensor([1., 1.])

# %%
Q_mean
# Out:
# tensor(37., grad_fn=<MeanBackward0>)

# %%
torch.linspace(1,10,5)
# Out:
# tensor([ 1.0000,  3.2500,  5.5000,  7.7500, 10.0000])

# %%
x = torch.ones(2, 2, requires_grad=True)
y = x + 2
z = y * y * 3
z_mean = z.mean()
z_mean.backward()    #等价z_mean.backward(torch.tensor(1.))
print(x.grad)
# Out:
# tensor([[4.5000, 4.5000],
#         [4.5000, 4.5000]])
